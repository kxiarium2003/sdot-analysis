# %% [markdown]
# ### 라이브러리 임포트

# %%
# --------------------------------------------------
# [1] 라이브러리 임포트 및 시각화 설정 
# --------------------------------------------------
import duckdb
import polars as pl
import pandas as pd
import os
import platform
import matplotlib.pyplot as plt
import seaborn as sns

# Polars, Pandas 출력 옵션 설정
pl.Config.set_tbl_rows(10)
pd.set_option('display.max_columns', 100)

# 🚨 반드시 Seaborn 임포트 이후에 폰트 설정 실행
if platform.system() == 'Darwin':  # Mac 환경
    plt.rc('font', family='Apple SD Gothic Neo')
elif platform.system() == 'Windows':  # Windows 환경
    plt.rc('font', family='Malgun Gothic')
else:  # Linux (Google Colab 등) 환경
    plt.rc('font', family='NanumGothic')

# 마이너스 기호 깨짐 방지
plt.rcParams['axes.unicode_minus'] = False

# %% [markdown]
# ### 데이터 로드

# %%
# --------------------------------------------------
# [2] 파일 경로 설정 및 데이터 로드
# --------------------------------------------------
BASE_DIR = os.path.abspath('..')
PARQUET_PATH = os.path.join(BASE_DIR, 'data', 'processed', 'sdot_final_mapped.parquet')

print(f"데이터 경로: {PARQUET_PATH}")
print(f"파일 존재 여부: {os.path.exists(PARQUET_PATH)}\n")

# DuckDB에 Parquet 파일을 뷰(v_sdot)로 즉시 등록
# -> 메모리를 적게 차지하며, 이후 SQL 쿼리에서 'v_sdot' 테이블명으로 바로 호출 가능
duckdb.sql(f"CREATE OR REPLACE VIEW v_sdot AS SELECT * FROM read_parquet('{PARQUET_PATH}')")

# --------------------------------------------------
# [3] 데이터 정상 로드 확인
# --------------------------------------------------
query_check = """
    SELECT * 
    FROM v_sdot
    LIMIT 5
"""
print("📌 [데이터 미리보기]")
display(duckdb.sql(query_check).pl())
# Out:
# 데이터 경로: /Users/gomdori/Documents/Git/sdot-analysis/data/processed/sdot_final_mapped.parquet
# 파일 존재 여부: True
#
# 📌 [데이터 미리보기]
# shape: (5, 134)
# ┌────────────┬────────────┬──────────┬──────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ measure_ti ┆ sensor_id  ┆ temp_max ┆ temp_avg ┆ … ┆ lat       ┆ lon       ┆ address   ┆ district │
# │ me         ┆ ---        ┆ ---      ┆ ---      ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---      │
# │ ---        ┆ str        ┆ str      ┆ f64      ┆   ┆ f64       ┆ f64       ┆ str       ┆ str      │
# │ str        ┆            ┆          ┆          ┆   ┆           ┆           ┆           ┆          │
# ╞════════════╪════════════╪══════════╪══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 2020.4.4   ┆ V02Q194007 ┆ null     ┆ 13.2     ┆ … ┆ 37.542549 ┆ 126.84031 ┆ 서울특별  ┆ 강서구   │
# │ 10:00      ┆ 8          ┆          ┆          ┆   ┆           ┆ 3         ┆ 시 강서구 ┆          │
# │            ┆            ┆          ┆          ┆   ┆           ┆           ┆ 화곡로27  ┆          │
# │            ┆            ┆          ┆          ┆   ┆           ┆           ┆ 길 16     ┆          │
# │ 2020.4.4   ┆ V02Q194007 ┆ null     ┆ 15.0     ┆ … ┆ 37.542549 ┆ 126.84031 ┆ 서울특별  ┆ 강서구   │
# │ 16:00      ┆ 8          ┆          ┆          ┆   ┆           ┆ 3         ┆ 시 강서구 ┆          │
# │            ┆            ┆          ┆          ┆   ┆           ┆           ┆ 화곡로27  ┆          │
# │            ┆            ┆          ┆          ┆   ┆           ┆           ┆ 길 16     ┆          │
# │ 2020.4.4   ┆ V02Q194007 ┆ null     ┆ 9.2      ┆ … ┆ 37.542549 ┆ 126.84031 ┆ 서울특별  ┆ 강서구   │
# │ 22:00      ┆ 8          ┆          ┆          ┆   ┆           ┆ 3         ┆ 시 강서구 ┆          │
# │            ┆            ┆          ┆          ┆   ┆           ┆           ┆ 화곡로27  ┆          │
# │            ┆            ┆          ┆          ┆   ┆           ┆           ┆ 길 16     ┆          │
# │ 2020.4.5   ┆ V02Q194007 ┆ null     ┆ 6.3      ┆ … ┆ 37.542549 ┆ 126.84031 ┆ 서울특별  ┆ 강서구   │
# │ 4:00       ┆ 8          ┆          ┆          ┆   ┆           ┆ 3         ┆ 시 강서구 ┆          │
# │            ┆            ┆          ┆          ┆   ┆           ┆           ┆ 화곡로27  ┆          │
# │            ┆            ┆          ┆          ┆   ┆           ┆           ┆ 길 16     ┆          │
# │ 2020.4.5   ┆ V02Q194007 ┆ null     ┆ 9.0      ┆ … ┆ 37.542549 ┆ 126.84031 ┆ 서울특별  ┆ 강서구   │
# │ 10:00      ┆ 8          ┆          ┆          ┆   ┆           ┆ 3         ┆ 시 강서구 ┆          │
# │            ┆            ┆          ┆          ┆   ┆           ┆           ┆ 화곡로27  ┆          │
# │            ┆            ┆          ┆          ┆   ┆           ┆           ┆ 길 16     ┆          │
# └────────────┴────────────┴──────────┴──────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %% [markdown]
# # 소음 및 진동 지표별 결측률

# %%
# 분석 대상 기상 컬럼
noise_vibe_cols = ['noise_min', 'noise_avg', 'noise_max', 
                   'vibe_x_min_g', 'vibe_x_avg_g', 'vibe_x_max_g',
                   'vibe_y_min_g', 'vibe_y_avg_g', 'vibe_y_max_g', 
                   'vibe_z_min_g', 'vibe_z_avg_g', 'vibe_z_max_g',
                   'vibe_x_min_mms', 'vibe_x_avg_mms', 'vibe_x_max_mms',
                   'vibe_y_min_mms', 'vibe_y_avg_mms', 'vibe_y_max_mms',
                   'vibe_z_min_mms', 'vibe_z_avg_mms', 'vibe_z_max_mms']

# DuckDB를 이용해 각 컬럼별 NULL 카운트 및 총 행 수 계산
null_queries = []
for col in noise_vibe_cols:
    null_queries.append(f"SUM(CASE WHEN {col} IS NULL THEN 1 ELSE 0 END) * 100.0 / COUNT(*) AS {col}_null_pct")

query_missing = f"SELECT {', '.join(null_queries)} FROM v_sdot"
df_missing = duckdb.sql(query_missing).pl().to_pandas().T
df_missing.columns = ['결측률(%)']
df_missing = df_missing.sort_values(by='결측률(%)', ascending=False)

plt.figure(figsize=(10, 6))
sns.barplot(x=df_missing['결측률(%)'], y=df_missing.index, hue=df_missing.index, palette='Reds_r', legend=False)

plt.title("소음 및 진동 지표별 결측률 (%)", fontsize=16, pad=15)
plt.xlabel("결측률 (%)", fontsize=12)
plt.ylabel("측정 항목", fontsize=12)
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# # 연도별 월별 결측률 시각화

# %%
import duckdb
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import math

noise_vibe_cols = ['noise_avg', 'vibe_x_avg_g', 'vibe_y_avg_g', 'vibe_z_avg_g', 'vibe_x_avg_mms', 'vibe_y_avg_mms', 'vibe_z_avg_mms']

# 1. 쿼리 생성: 모든 컬럼의 연-월별 결측률을 단일 쿼리로 계산
null_pct_sqls = [f"ROUND(SUM(CASE WHEN {col} IS NULL THEN 1 ELSE 0 END) * 100.0 / COUNT(*), 1) AS {col}" for col in noise_vibe_cols]
null_pct_sql_str = ",\n        ".join(null_pct_sqls)

query_all_seasonal = f"""
    SELECT 
        EXTRACT(year FROM measure_timestamp) AS year,
        EXTRACT(month FROM measure_timestamp) AS month,
        {null_pct_sql_str}
    FROM v_sdot
    GROUP BY year, month
    ORDER BY year, month
"""
df_all_seasonal = duckdb.sql(query_all_seasonal).df()

# --------------------------------------------------
# [시각화 1] 전체 지표 결측률 타임라인 히트맵 (거시적 관점)
# --------------------------------------------------
# 'YYYY-MM' 형식의 파생 컬럼 생성
df_all_seasonal['year_month'] = df_all_seasonal['year'].astype(int).astype(str) + '-' + df_all_seasonal['month'].astype(int).astype(str).str.zfill(2)
df_heatmap = df_all_seasonal.set_index('year_month')[noise_vibe_cols].T

plt.figure(figsize=(22, 10))
sns.heatmap(df_heatmap, cmap='Reds', annot=False, cbar_kws={'label': '결측률 (%)'})
plt.title("전체 기상 지표의 연도-월별 결측률 흐름 (Heatmap)", fontsize=18, pad=15)
plt.xlabel("연도-월", fontsize=12)
plt.ylabel("측정 항목", fontsize=12)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# --------------------------------------------------
# [시각화 2] 지표별 연도/월별 3열 Grid 바 차트 (미시적 관점)
# --------------------------------------------------
years = sorted(df_all_seasonal['year'].dropna().unique())
cols = 3
rows = math.ceil(len(years) / cols)

def plot_seasonal_nulls_for_item(item_name):
    fig, axes = plt.subplots(nrows=rows, ncols=cols, figsize=(16, 4 * rows))
    axes = axes.flatten()
    
    for i, year in enumerate(years):
        ax = axes[i]
        year_data = df_all_seasonal[df_all_seasonal['year'] == year]
        
        sns.barplot(data=year_data, x='month', y=item_name, palette='coolwarm', ax=ax)
        
        ax.set_title(f"[{item_name}] {int(year)}년 월별 결측률", fontsize=14, pad=10)
        ax.set_xlabel("월 (Month)", fontsize=10)
        ax.set_ylabel("결측률 (%)", fontsize=10)
        ax.set_ylim(0, 110) # 텍스트 잘림 방지
        ax.grid(axis='y', linestyle='--', alpha=0.7)
        
        # 막대 위에 % 표시
        for p in ax.patches:
            height = p.get_height()
            if height > 0:
                ax.annotate(f"{height}%", 
                            (p.get_x() + p.get_width() / 2., height), 
                            ha='center', va='bottom', fontsize=9, color='black', 
                            xytext=(0, 4), textcoords='offset points')
                            
    # 데이터가 없는 남은 subplot 숨기기
    for j in range(len(years), len(axes)):
        fig.delaxes(axes[j])
        
    plt.tight_layout()
    plt.show()

# 21개 지표 모두에 대해 Grid 그래프 반복 출력
for col in noise_vibe_cols:
    plot_seasonal_nulls_for_item(col)
# Out:
# /var/folders/c6/_5q2k4291yj3lw8b4k_0fc8m0000gn/T/ipykernel_69886/2825119052.py:55: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=year_data, x='month', y=item_name, palette='coolwarm', ax=ax)
# /var/folders/c6/_5q2k4291yj3lw8b4k_0fc8m0000gn/T/ipykernel_69886/2825119052.py:55: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=year_data, x='month', y=item_name, palette='coolwarm', ax=ax)
# /var/folders/c6/_5q2k4291yj3lw8b4k_0fc8m0000gn/T/ipykernel_69886/2825119052.py:55: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=year_data, x='month', y=item_name, palette='coolwarm', ax=ax)
# /var/folders/c6/_5q2k4291yj3lw8b4k_0fc8m0000gn/T/ipykernel_69886/2825119052.py:55: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=year_data, x='month', y=item_name, palette='coolwarm', ax=ax)
# /var/folders/c6/_5q2k4291yj3lw8b4k_0fc8m0000gn/T/ipykernel_69886/2825119052.py:55: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=year_data, x='month', y=item_name, palette='coolwarm', ax=ax)
# /var/folders/c6/_5q2k4291yj3lw8b4k_0fc8m0000gn/T/ipykernel_69886/2825119052.py:55: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=year_data, x='month', y=item_name, palette='coolwarm', ax=ax)
# /var/folders/c6/_5q2k4291yj3lw8b4k_0fc8m0000gn/T/ipykernel_69886/2825119052.py:55: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=year_data, x='month', y=item_name, palette='coolwarm', ax=ax)
# /var/folders/c6/_5q2k4291yj3lw8b4k_0fc8m0000gn/T/ipykernel_69886/2825119052.py:55: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=year_data, x='month', y=item_name, palette='coolwarm', ax=ax)
# /var/folders/c6/_5q2k4291yj3lw8b4k_0fc8m0000gn/T/ipykernel_69886/2825119052.py:55: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=year_data, x='month', y=item_name, palette='coolwarm', ax=ax)
# /var/folders/c6/_5q2k4291yj3lw8b4k_0fc8m0000gn/T/ipykernel_69886/2825119052.py:55: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=year_data, x='month', y=item_name, palette='coolwarm', ax=ax)
# /var/folders/c6/_5q2k4291yj3lw8b4k_0fc8m0000gn/T/ipykernel_69886/2825119052.py:55: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=year_data, x='month', y=item_name, palette='coolwarm', ax=ax)
# /var/folders/c6/_5q2k4291yj3lw8b4k_0fc8m0000gn/T/ipykernel_69886/2825119052.py:55: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=year_data, x='month', y=item_name, palette='coolwarm', ax=ax)
# /var/folders/c6/_5q2k4291yj3lw8b4k_0fc8m0000gn/T/ipykernel_69886/2825119052.py:55: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=year_data, x='month', y=item_name, palette='coolwarm', ax=ax)
# /var/folders/c6/_5q2k4291yj3lw8b4k_0fc8m0000gn/T/ipykernel_69886/2825119052.py:55: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=year_data, x='month', y=item_name, palette='coolwarm', ax=ax)
# /var/folders/c6/_5q2k4291yj3lw8b4k_0fc8m0000gn/T/ipykernel_69886/2825119052.py:55: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=year_data, x='month', y=item_name, palette='coolwarm', ax=ax)
# /var/folders/c6/_5q2k4291yj3lw8b4k_0fc8m0000gn/T/ipykernel_69886/2825119052.py:55: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=year_data, x='month', y=item_name, palette='coolwarm', ax=ax)
# /var/folders/c6/_5q2k4291yj3lw8b4k_0fc8m0000gn/T/ipykernel_69886/2825119052.py:55: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=year_data, x='month', y=item_name, palette='coolwarm', ax=ax)
# /var/folders/c6/_5q2k4291yj3lw8b4k_0fc8m0000gn/T/ipykernel_69886/2825119052.py:55: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=year_data, x='month', y=item_name, palette='coolwarm', ax=ax)
# /var/folders/c6/_5q2k4291yj3lw8b4k_0fc8m0000gn/T/ipykernel_69886/2825119052.py:55: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=year_data, x='month', y=item_name, palette='coolwarm', ax=ax)
# /var/folders/c6/_5q2k4291yj3lw8b4k_0fc8m0000gn/T/ipykernel_69886/2825119052.py:55: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=year_data, x='month', y=item_name, palette='coolwarm', ax=ax)
# /var/folders/c6/_5q2k4291yj3lw8b4k_0fc8m0000gn/T/ipykernel_69886/2825119052.py:55: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=year_data, x='month', y=item_name, palette='coolwarm', ax=ax)
# /var/folders/c6/_5q2k4291yj3lw8b4k_0fc8m0000gn/T/ipykernel_69886/2825119052.py:55: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=year_data, x='month', y=item_name, palette='coolwarm', ax=ax)
# /var/folders/c6/_5q2k4291yj3lw8b4k_0fc8m0000gn/T/ipykernel_69886/2825119052.py:55: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=year_data, x='month', y=item_name, palette='coolwarm', ax=ax)
# /var/folders/c6/_5q2k4291yj3lw8b4k_0fc8m0000gn/T/ipykernel_69886/2825119052.py:55: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=year_data, x='month', y=item_name, palette='coolwarm', ax=ax)
# /var/folders/c6/_5q2k4291yj3lw8b4k_0fc8m0000gn/T/ipykernel_69886/2825119052.py:55: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=year_data, x='month', y=item_name, palette='coolwarm', ax=ax)
# /var/folders/c6/_5q2k4291yj3lw8b4k_0fc8m0000gn/T/ipykernel_69886/2825119052.py:55: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=year_data, x='month', y=item_name, palette='coolwarm', ax=ax)
# /var/folders/c6/_5q2k4291yj3lw8b4k_0fc8m0000gn/T/ipykernel_69886/2825119052.py:55: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=year_data, x='month', y=item_name, palette='coolwarm', ax=ax)
# /var/folders/c6/_5q2k4291yj3lw8b4k_0fc8m0000gn/T/ipykernel_69886/2825119052.py:55: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=year_data, x='month', y=item_name, palette='coolwarm', ax=ax)
# /var/folders/c6/_5q2k4291yj3lw8b4k_0fc8m0000gn/T/ipykernel_69886/2825119052.py:55: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=year_data, x='month', y=item_name, palette='coolwarm', ax=ax)
# /var/folders/c6/_5q2k4291yj3lw8b4k_0fc8m0000gn/T/ipykernel_69886/2825119052.py:55: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=year_data, x='month', y=item_name, palette='coolwarm', ax=ax)
# /var/folders/c6/_5q2k4291yj3lw8b4k_0fc8m0000gn/T/ipykernel_69886/2825119052.py:55: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=year_data, x='month', y=item_name, palette='coolwarm', ax=ax)
# /var/folders/c6/_5q2k4291yj3lw8b4k_0fc8m0000gn/T/ipykernel_69886/2825119052.py:55: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=year_data, x='month', y=item_name, palette='coolwarm', ax=ax)
# /var/folders/c6/_5q2k4291yj3lw8b4k_0fc8m0000gn/T/ipykernel_69886/2825119052.py:55: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=year_data, x='month', y=item_name, palette='coolwarm', ax=ax)
# /var/folders/c6/_5q2k4291yj3lw8b4k_0fc8m0000gn/T/ipykernel_69886/2825119052.py:55: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=year_data, x='month', y=item_name, palette='coolwarm', ax=ax)
# /var/folders/c6/_5q2k4291yj3lw8b4k_0fc8m0000gn/T/ipykernel_69886/2825119052.py:55: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=year_data, x='month', y=item_name, palette='coolwarm', ax=ax)
# /var/folders/c6/_5q2k4291yj3lw8b4k_0fc8m0000gn/T/ipykernel_69886/2825119052.py:55: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=year_data, x='month', y=item_name, palette='coolwarm', ax=ax)
# /var/folders/c6/_5q2k4291yj3lw8b4k_0fc8m0000gn/T/ipykernel_69886/2825119052.py:55: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=year_data, x='month', y=item_name, palette='coolwarm', ax=ax)
# /var/folders/c6/_5q2k4291yj3lw8b4k_0fc8m0000gn/T/ipykernel_69886/2825119052.py:55: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=year_data, x='month', y=item_name, palette='coolwarm', ax=ax)
# /var/folders/c6/_5q2k4291yj3lw8b4k_0fc8m0000gn/T/ipykernel_69886/2825119052.py:55: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=year_data, x='month', y=item_name, palette='coolwarm', ax=ax)
# /var/folders/c6/_5q2k4291yj3lw8b4k_0fc8m0000gn/T/ipykernel_69886/2825119052.py:55: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=year_data, x='month', y=item_name, palette='coolwarm', ax=ax)
# /var/folders/c6/_5q2k4291yj3lw8b4k_0fc8m0000gn/T/ipykernel_69886/2825119052.py:55: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=year_data, x='month', y=item_name, palette='coolwarm', ax=ax)
# /var/folders/c6/_5q2k4291yj3lw8b4k_0fc8m0000gn/T/ipykernel_69886/2825119052.py:55: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=year_data, x='month', y=item_name, palette='coolwarm', ax=ax)
# /var/folders/c6/_5q2k4291yj3lw8b4k_0fc8m0000gn/T/ipykernel_69886/2825119052.py:55: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=year_data, x='month', y=item_name, palette='coolwarm', ax=ax)
# /var/folders/c6/_5q2k4291yj3lw8b4k_0fc8m0000gn/T/ipykernel_69886/2825119052.py:55: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=year_data, x='month', y=item_name, palette='coolwarm', ax=ax)
# /var/folders/c6/_5q2k4291yj3lw8b4k_0fc8m0000gn/T/ipykernel_69886/2825119052.py:55: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=year_data, x='month', y=item_name, palette='coolwarm', ax=ax)
# /var/folders/c6/_5q2k4291yj3lw8b4k_0fc8m0000gn/T/ipykernel_69886/2825119052.py:55: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=year_data, x='month', y=item_name, palette='coolwarm', ax=ax)
# /var/folders/c6/_5q2k4291yj3lw8b4k_0fc8m0000gn/T/ipykernel_69886/2825119052.py:55: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=year_data, x='month', y=item_name, palette='coolwarm', ax=ax)
# /var/folders/c6/_5q2k4291yj3lw8b4k_0fc8m0000gn/T/ipykernel_69886/2825119052.py:55: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=year_data, x='month', y=item_name, palette='coolwarm', ax=ax)
# /var/folders/c6/_5q2k4291yj3lw8b4k_0fc8m0000gn/T/ipykernel_69886/2825119052.py:55: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=year_data, x='month', y=item_name, palette='coolwarm', ax=ax)

# %% [markdown]
# # 소음 및 진동 지표별 수집 간격

# %%
noise_vibe_cols = ['noise_min', 'noise_avg', 'noise_max', 
                   'vibe_x_min_g', 'vibe_x_avg_g', 'vibe_x_max_g',
                   'vibe_y_min_g', 'vibe_y_avg_g', 'vibe_y_max_g', 
                   'vibe_z_min_g', 'vibe_z_avg_g', 'vibe_z_max_g',
                   'vibe_x_min_mms', 'vibe_x_avg_mms', 'vibe_x_max_mms',
                   'vibe_y_min_mms', 'vibe_y_avg_mms', 'vibe_y_max_mms',
                   'vibe_z_min_mms', 'vibe_z_avg_mms', 'vibe_z_max_mms']

# 1. SELECT 절에서 모든 대상 컬럼을 명시적으로 DOUBLE형으로 캐스팅
casted_cols = [f"TRY_CAST({col} AS DOUBLE) AS {col}" for col in noise_vibe_cols]
noise_vibe_cols_cast_str = ", ".join(casted_cols)
# 2. UNPIVOT ON 절에는 컬럼 이름만 필요
noise_vibe_cols_str = ", ".join(noise_vibe_cols) 

query_interval = f"""
    WITH gap_calc AS (
        SELECT 
            sensor_id_matched,
            measure_timestamp,
            DATE_DIFF('minute', 
                      LAG(measure_timestamp) OVER(PARTITION BY sensor_id_matched ORDER BY measure_timestamp), 
                      measure_timestamp) AS time_gap_minutes,
            {noise_vibe_cols_cast_str}
        FROM v_sdot
    ),
    unpivoted_gaps AS (
        UNPIVOT gap_calc
        ON {noise_vibe_cols_str}
        INTO
            NAME measure_type
            VALUE measure_value
    )
    SELECT 
        measure_type AS 측정_항목,
        MEDIAN(time_gap_minutes) AS 중앙값_간격_분,
        ROUND(AVG(time_gap_minutes), 1) AS 평균_간격_분
    FROM unpivoted_gaps
    WHERE measure_value IS NOT NULL
      AND time_gap_minutes > 0  
    GROUP BY measure_type
    ORDER BY 중앙값_간격_분 ASC, 측정_항목 ASC
"""
df_interval = duckdb.sql(query_interval).pl().to_pandas()

print("📌 [소음 및 진동 지표별 실제 측정 주기]")
display(df_interval)
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# 📌 [소음 및 진동 지표별 실제 측정 주기]
#              측정_항목  중앙값_간격_분  평균_간격_분
# 0        noise_avg      60.0    118.2
# 1        noise_max      60.0    126.0
# 2        noise_min      60.0    126.0
# 3     vibe_x_avg_g      60.0     64.8
# 4   vibe_x_avg_mms      60.0    132.1
# 5     vibe_x_max_g      60.0     64.8
# 6   vibe_x_max_mms      60.0    132.1
# 7   vibe_x_min_mms      60.0    132.1
# 8     vibe_y_avg_g      60.0     64.8
# 9   vibe_y_avg_mms      60.0    132.1
# 10    vibe_y_max_g      60.0     64.8
# 11  vibe_y_max_mms      60.0    132.1
# 12  vibe_y_min_mms      60.0    132.1
# 13    vibe_z_avg_g      60.0     64.8
# 14  vibe_z_avg_mms      60.0    132.1
# 15    vibe_z_max_g      60.0     64.8
# 16  vibe_z_max_mms      60.0    132.1
# 17  vibe_z_min_mms      60.0    132.1

# %% [markdown]
# # 소음 및 진동 지표별 수집 누락 비율

# %%
query_missing_freq = f"""
    WITH unpivoted_data AS (
        UNPIVOT (
            SELECT 
                sensor_id_matched, 
                measure_timestamp, 
                {noise_vibe_cols_cast_str}
            FROM v_sdot
        )
        ON {noise_vibe_cols_str}
        INTO
            NAME measure_type
            VALUE measure_value
    ),
    gap_calc AS (
        SELECT 
            measure_type,
            DATE_DIFF('minute', 
                      LAG(measure_timestamp) OVER(PARTITION BY sensor_id_matched, measure_type ORDER BY measure_timestamp), 
                      measure_timestamp) AS time_gap_minutes
        FROM unpivoted_data
        WHERE measure_value IS NOT NULL
    )
    SELECT 
        measure_type AS 측정_항목,
        COUNT(*) AS 총_수집_횟수,
        SUM(CASE WHEN time_gap_minutes > 65 THEN 1 ELSE 0 END) AS 지연_및_누락_횟수,
        ROUND(SUM(CASE WHEN time_gap_minutes > 65 THEN 1 ELSE 0 END) * 100.0 / COUNT(*), 2) AS 누락_발생_비율_pct
    FROM gap_calc
    WHERE time_gap_minutes > 0  
    GROUP BY measure_type
    ORDER BY 누락_발생_비율_pct DESC
"""
df_missing_freq = duckdb.sql(query_missing_freq).pl().to_pandas()

print("📌 [소음 및 진동 지표별 통신 단절 및 수집 누락 발생 비율]")
display(df_missing_freq)
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# 📌 [소음 및 진동 지표별 통신 단절 및 수집 누락 발생 비율]
#              측정_항목   총_수집_횟수 지연_및_누락_횟수  누락_발생_비율_pct
# 0   vibe_z_min_mms  19680434     997748          5.07
# 1   vibe_z_max_mms  19681102     998416          5.07
# 2   vibe_x_avg_mms  19683109     997082          5.07
# 3   vibe_x_min_mms  19680436     997748          5.07
# 4   vibe_y_min_mms  19680436     997748          5.07
# 5   vibe_z_avg_mms  19683107     997082          5.07
# 6   vibe_x_max_mms  19681103     998415          5.07
# 7   vibe_y_avg_mms  19683109     997082          5.07
# 8   vibe_y_max_mms  19681103     998415          5.07
# 9        noise_max  24619090    1237317          5.03
# 10       noise_min  24618244    1236471          5.02
# 11       noise_avg  28223965    1339037          4.74
# 12    vibe_y_avg_g   3928813     101683          2.59
# 13    vibe_x_avg_g   3928014     101682          2.59
# 14    vibe_x_max_g   3928158     101767          2.59
# 15    vibe_y_max_g   3928164     101758          2.59
# 16    vibe_z_max_g   3977489     102482          2.58
# 17    vibe_z_avg_g   3975783     101966          2.56

# %% [markdown]
# # 전체 기간 결측 발생 비율 시각화

# %%
import duckdb
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# 한글 폰트 설정
# plt.rc('font', family='Malgun Gothic') # Windows
plt.rc('font', family='AppleGothic') # Mac
plt.rcParams['axes.unicode_minus'] = False

noise_vibe_cols = ['noise_min', 'noise_avg', 'noise_max', 
                   'vibe_x_min_g', 'vibe_x_avg_g', 'vibe_x_max_g',
                   'vibe_y_min_g', 'vibe_y_avg_g', 'vibe_y_max_g', 
                   'vibe_z_min_g', 'vibe_z_avg_g', 'vibe_z_max_g',
                   'vibe_x_min_mms', 'vibe_x_avg_mms', 'vibe_x_max_mms',
                   'vibe_y_min_mms', 'vibe_y_avg_mms', 'vibe_y_max_mms',
                   'vibe_z_min_mms', 'vibe_z_avg_mms', 'vibe_z_max_mms']

# --------------------------------------------------
# 1. 초경량화 데이터 추출: DISTINCT DATE() 활용
# --------------------------------------------------
# 수백만 건의 원본 데이터 대신, "결측이 발생한 날짜"만 중복 없이 가져옵니다.
# 아무리 데이터가 많아도 (전체 일수 x 20개 지표) 건수 이상을 넘지 않아 매우 가볍습니다.
queries = []
for col in noise_vibe_cols:
    q = f"""
        SELECT DISTINCT DATE(measure_timestamp) AS measure_date, '{col}' AS indicator 
        FROM v_sdot 
        WHERE {col} IS NULL
    """
    queries.append(q)

query_lightweight = " UNION ALL ".join(queries)

# 쿼리 실행 (순식간에 끝납니다!)
df_missing_scatter = duckdb.sql(query_lightweight).df()
df_missing_scatter['measure_date'] = pd.to_datetime(df_missing_scatter['measure_date'])

# --------------------------------------------------
# 2. 산점도(Scatter Plot) 시각화
# --------------------------------------------------
plt.figure(figsize=(16, 8))

if df_missing_scatter.empty:
    print("🚨 결측 데이터가 없습니다.")
else:
    # y축 정렬
    order_list = list(reversed(noise_vibe_cols))
    
    sns.scatterplot(
        data=df_missing_scatter, 
        x='measure_date', 
        y='indicator', 
        hue='indicator',   
        marker='|',        
        s=100,             # 일 단위이므로 마커 크기를 키워 연속성을 강조
        alpha=0.6,         
        legend=False       
    )

    plt.title('소음 및 진동 지표별 전체 기간 결측 발생 분포 (일 단위 압축)', fontsize=18, fontweight='bold', pad=15)
    plt.xlabel('측정 일자', fontsize=14, labelpad=10)
    plt.ylabel('소음 및 진동 측정 항목', fontsize=14, labelpad=10)

    plt.grid(axis='x', linestyle='--', alpha=0.7)
    plt.grid(axis='y', linestyle='-', alpha=0.2)

    plt.yticks(fontsize=11)
    plt.xticks(fontsize=11, rotation=45)

    plt.tight_layout()
    plt.show()
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))

# %% [markdown]
# # 자치구별 시간대별 소음 및 진동

# %%
import duckdb
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# 한글 폰트 설정
# plt.rc('font', family='Malgun Gothic') # Windows
plt.rc('font', family='AppleGothic') # Mac
plt.rcParams['axes.unicode_minus'] = False

# --------------------------------------------------
# [1] 시간대별 평균 소음 분석 
# --------------------------------------------------
query_noise_time = """
    SELECT 
        CAST(EXTRACT(HOUR FROM TRY_CAST(measure_timestamp AS TIMESTAMP)) AS INTEGER) AS hour_of_day,
        AVG(TRY_CAST(noise_avg AS DOUBLE)) AS avg_noise
    FROM v_sdot
    WHERE EXTRACT(YEAR FROM TRY_CAST(measure_timestamp AS TIMESTAMP)) BETWEEN 2024 AND 2026
    GROUP BY hour_of_day
    ORDER BY hour_of_day
"""
df_noise_time = duckdb.sql(query_noise_time).df()

# --------------------------------------------------
# [2] 자치구별 진동(mms) / 소음 패턴 분석 
# --------------------------------------------------
query_gu_pattern = """
    SELECT 
        district, 
        AVG(TRY_CAST(noise_avg AS DOUBLE)) AS avg_noise,
        AVG(TRY_CAST(vibe_x_avg_mms AS DOUBLE)) AS avg_vibe  -- mms 단위로 수정!
    FROM v_sdot
    WHERE EXTRACT(YEAR FROM TRY_CAST(measure_timestamp AS TIMESTAMP)) BETWEEN 2024 AND 2026
      AND district IS NOT NULL
    GROUP BY district
    ORDER BY avg_noise DESC
"""
df_gu_pattern = duckdb.sql(query_gu_pattern).df()

# --------------------------------------------------
# 시각화 (1x2 Subplot)
# --------------------------------------------------
fig, axes = plt.subplots(1, 2, figsize=(20, 7))

# 1. 시간대별 소음 추이
sns.lineplot(data=df_noise_time, x='hour_of_day', y='avg_noise', ax=axes[0], marker='o', color='crimson', linewidth=2)
axes[0].set_title('서울 전체 시간대별 평균 소음 추이 (2024~2026)', fontsize=16, pad=15)
axes[0].set_xlabel('시간 (Hour of Day)', fontsize=12)
axes[0].set_ylabel('평균 소음 (dB)', fontsize=12)
axes[0].set_xticks(range(0, 24))
axes[0].grid(True, linestyle='--', alpha=0.6)
axes[0].axvspan(23, 24, color='navy', alpha=0.1)
axes[0].axvspan(0, 5, color='navy', alpha=0.1, label='심야 시간대 (23시~05시)')
axes[0].legend()

# 2. 자치구별 진동 vs 소음 산점도
sns.scatterplot(data=df_gu_pattern, x='avg_vibe', y='avg_noise', ax=axes[1], s=100, color='darkorange', edgecolor='k')
axes[1].set_title('자치구별 평균 소음 vs 진동 패턴', fontsize=16, pad=15)
axes[1].set_xlabel('평균 진동 수치 (mm/s)', fontsize=12)  # 단위 라벨 수정
axes[1].set_ylabel('평균 소음 (dB)', fontsize=12)
axes[1].grid(True, linestyle='--', alpha=0.6)

# 텍스트 라벨링 (간격은 데이터 스케일에 따라 조정될 수 있음)
for i in range(df_gu_pattern.shape[0]):
    axes[1].text(df_gu_pattern['avg_vibe'][i], 
                 df_gu_pattern['avg_noise'][i] + 0.1, 
                 df_gu_pattern['district'][i], 
                 fontsize=9, ha='center')

plt.tight_layout()
plt.show()
# Out:
# posx and posy should be finite values
# posx and posy should be finite values

# %%
import duckdb
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# 한글 폰트 설정
# plt.rc('font', family='Malgun Gothic') # Windows
plt.rc('font', family='AppleGothic') # Mac
plt.rcParams['axes.unicode_minus'] = False

# --------------------------------------------------
# [1] 자치구별 & 시간대별 평균 소음 쿼리
# --------------------------------------------------
query_noise_district_time = """
    SELECT 
        district,
        CAST(EXTRACT(HOUR FROM TRY_CAST(measure_timestamp AS TIMESTAMP)) AS INTEGER) AS hour_of_day,
        AVG(TRY_CAST(noise_avg AS DOUBLE)) AS avg_noise
    FROM v_sdot
    WHERE EXTRACT(YEAR FROM TRY_CAST(measure_timestamp AS TIMESTAMP)) BETWEEN 2024 AND 2026
      AND district IS NOT NULL
    GROUP BY district, hour_of_day
    ORDER BY district, hour_of_day
"""
df_dist_time = duckdb.sql(query_noise_district_time).df()

# --------------------------------------------------
# [2] 히트맵을 위한 데이터 피벗 (Pivot)
# --------------------------------------------------
# index=자치구, columns=시간대, values=평균소음 형태로 변환
df_pivot = df_dist_time.pivot(index='district', columns='hour_of_day', values='avg_noise')

# 보기 편하도록 '하루 전체 평균 소음'이 높은 자치구 순으로 행(Row) 정렬
df_pivot['daily_avg'] = df_pivot.mean(axis=1)
df_pivot = df_pivot.sort_values('daily_avg', ascending=False).drop(columns=['daily_avg'])

# --------------------------------------------------
# [3] 시각화 (Heatmap)
# --------------------------------------------------
plt.figure(figsize=(16, 10))

# YlOrRd (Yellow-Orange-Red) 컬러맵을 사용하여 소음이 높을수록 붉고 진하게 표현
sns.heatmap(df_pivot, cmap='YlOrRd', annot=False, fmt=".1f", linewidths=.5, cbar_kws={'label': '평균 소음 (dB)'})

plt.title('자치구별 및 시간대별 평균 소음 응집도 (2024~2026)', fontsize=18, pad=20)
plt.xlabel('시간 (Hour of Day)', fontsize=14)
plt.ylabel('자치구', fontsize=14)

# 심야 시간대(23시~05시)를 시각적으로 분리하기 위해 세로선 추가 (선택 사항)
plt.axvline(x=23, color='blue', linestyle='--', alpha=0.5)
plt.axvline(x=6, color='blue', linestyle='--', alpha=0.5)

plt.tight_layout()
plt.show()
